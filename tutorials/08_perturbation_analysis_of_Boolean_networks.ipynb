# %% [markdown]
# # BoolForge Tutorial #8: Perturbation and sensitivity analysis of Boolean networks
#
# In this tutorial, we study how Boolean networks respond to perturbations.
#
# You will learn how to:
# - apply transient and permanent perturbations to node states,
# - examine how perturbations affect trajectories and attractors,
# - quantify robustness and fragility of individual nodes, and
# - explore network-wide sensitivity using ensemble perturbation experiments.
#
# Perturbation analysis provides insight into the stability and dynamical resilience of regulatory systems.

# %%
import boolforge
import numpy as np
import networkx as nx
